# %% [markdown]
# <a href="https://colab.research.google.com/github/komalchilke/cpp-programs/blob/main/multiplelinreg.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import LinearRegression
print("komal chilke\nBE21F06F014")

dataset = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/advertising.csv")
print ("\nDataset Head: \n")
print (dataset.head())
x = dataset [['TV', 'Radio', 'Newspaper']]
y = dataset ['Sales']
print ("\nIndependent Variables (X): \n")
print (x)

print ("\nDependent Variable (y): \n")
print (y)

from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split (x, y, test_size = 0.3, random_state = 100)
print ("\nTraining Data (x):\n")
print (x_train)
print ("\nTraining Data (y):\n")
print (y_train)
print ("\nTest Data (x):\n")
print (x_test)
print ("\nTest Data (y) :\n")
print (y_test)

multiple_LR = LinearRegression()
multiple_LR.fit(x_train, y_train)

print ("\nIntercept: ", multiple_LR. intercept_)
print ("\nCoeﬃcients:")
print (list (zip(x, multiple_LR.coef_)))

y_pred_mlr= multiple_LR.predict(x_test)

print ("\nPrediction for test set: \n\n {}".format (y_pred_mlr))

mlr_diff = pd.DataFrame ({'Actual value': y_test, 'Predicted value': y_pred_mlr})
print ("\nActual Vs Predicted: \n",mlr_diff.head())

from sklearn import metrics
meanAbErr = metrics.mean_absolute_error (y_test, y_pred_mlr)
meanSqErr = metrics.mean_squared_error (y_test, y_pred_mlr)
rootMeanSqErr = np.sqrt(metrics.mean_squared_error (y_test, y_pred_mlr))

print("\nModel Evaluation: ")
print('R squared: {:.2f}'.format (multiple_LR. score (x, y) *100))
print('Mean Absolute Error (MAE):', meanAbErr)
print('Mean Square Error (MSE): ', meanSqErr)
print('Root Mean Square Error (RMSE): ', rootMeanSqErr)
# Out:
# komal chilke
# BE21F06F014
#
# Dataset Head:
#
#       TV  Radio  Newspaper  Sales
# 0  230.1   37.8       69.2   22.1
# 1   44.5   39.3       45.1   10.4
# 2   17.2   45.9       69.3   12.0
# 3  151.5   41.3       58.5   16.5
# 4  180.8   10.8       58.4   17.9
#
# Independent Variables (X):
#
#         TV  Radio  Newspaper
# 0    230.1   37.8       69.2
# 1     44.5   39.3       45.1
# 2     17.2   45.9       69.3
# 3    151.5   41.3       58.5
# 4    180.8   10.8       58.4
# ..     ...    ...        ...
# 195   38.2    3.7       13.8
# 196   94.2    4.9        8.1
# 197  177.0    9.3        6.4
# 198  283.6   42.0       66.2
# 199  232.1    8.6        8.7
#
# [200 rows x 3 columns]
#
# Dependent Variable (y):
#
# 0      22.1
# 1      10.4
# 2      12.0
# 3      16.5
# 4      17.9
#        ...
# 195     7.6
# 196    14.0
# 197    14.8
# 198    25.5
# 199    18.4
# Name: Sales, Length: 200, dtype: float64
#
# Training Data (x):
#
#         TV  Radio  Newspaper
# ...
